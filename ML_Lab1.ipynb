# %% [markdown]
# <a href="https://colab.research.google.com/github/SikandarHussain6858/Machine-Learning/blob/main/ML_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TASK 1

# %%
import pandas as pd
df = pd.read_csv("/content/Students Social Media Addiction.csv")
df.head()
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# 2             TikTok                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
# ...

# %% [markdown]
# TASK 2

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f37140a7-fa71-4b3c-9bab-a60a9ce7a36e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f37140a7-fa71-4b3c-9bab-a60a9ce7a36e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/Students Social Media Addiction.csv")
df.head()
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# 2             TikTok                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
# ...

# %% [markdown]
# TASK 3

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/BindiChen/machine-learning/master/data-analysis/001-pandad-pipe-function/data/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !git clone https://github.com/BindiChen/machine-learning.git
# Out:
# Cloning into 'machine-learning'...
# remote: Enumerating objects: 928, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 928 (delta 6), reused 4 (delta 4), pack-reused 896 (from 2)
# Receiving objects: 100% (928/928), 12.04 MiB | 12.95 MiB/s, done.
# Resolving deltas: 100% (378/378), done.

# %% [markdown]
# TASK 4

# %%
import pandas as pd
df = pd.read_csv('/content/machine-learning/data-analysis/001-pandad-pipe-function/data/test.csv')
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# TASK 5

# %%
# 1. Download dataset
# !wget https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip

# 2. Download and rename
# !wget https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip -O new_cats_and_dogs_filtered.zip

# 3. Download to specific location
# !wget https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip -P /tmp/

# 4. Ignore SSL certificate (demo)
# !wget https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip --no-check-certificate

# 5. Create URL list file
# !echo "https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip" > dataset-urls.txt
# !echo "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv" >> dataset-urls.txt

# 6. Download multiple files
# !wget -i dataset-urls.txt

# 7. List files
# !ls
# Out:
# --2026-01-22 10:12:23--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.101.207, 142.250.141.207, 142.251.2.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.101.207|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2026-01-22 10:12:24 ERROR 403: Forbidden.
#
# --2026-01-22 10:12:24--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.101.207, 142.250.141.207, 142.251.2.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.101.207|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2026-01-22 10:12:24 ERROR 403: Forbidden.
#
# --2026-01-22 10:12:24--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/pima-indians-diabetes.data.csv")
df.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %% [markdown]
# TASK 6

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Students Social Media Addiction (1).csv")
df.head()
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# 2             TikTok                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
# ...

# %%
drive.flush_and_unmount()

# %% [markdown]
# TASK 7

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6a85c3cb-6e56-410c-a52f-bd5e701c1205" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a85c3cb-6e56-410c-a52f-bd5e701c1205">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# STEP 3: Set Kaggle config directory
import os
os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()

# %%
# !chmod 600 kaggle.json

# %%
# !pip install -q kaggle

# %%
# !kaggle competitions download -c titanic
# Out:
# ...
#   0% 0.00/34.1k [00:00<?, ?B/s]
# 100% 34.1k/34.1k [00:00<00:00, 141MB/s]

# %%
# !kaggle datasets download -d alexanderbader/forbes-billionaires-2021-30
# Out:
# Dataset URL: https://www.kaggle.com/datasets/alexanderbader/forbes-billionaires-2021-30
# License(s): CC0-1.0
# ...
#   0% 0.00/114k [00:00<?, ?B/s]
# 100% 114k/114k [00:00<00:00, 399MB/s]

# %%
# !unzip titanic.zip
# !unzip forbes-billionaires-2021-30.zip
# Out:
# Archive:  titanic.zip
#   inflating: gender_submission.csv
#   inflating: test.csv
#   inflating: train.csv
# Archive:  forbes-billionaires-2021-30.zip
#   inflating: forbes_billionaires_geo.csv
